# %%
import pandas as pd
import matplotlib.pyplot as plt
from shap_flow_util import read_csv_incl_timeindex

# %% [markdown]
# ## Visualize Data

# %%
version = 'v2'
directory = './data/{}'.format(version)
X = read_csv_incl_timeindex('{}/X_full.csv'.format(directory))
y_price = read_csv_incl_timeindex('{}/y_price_full.csv'.format(directory))
y_export = read_csv_incl_timeindex('{}/y_export_full.csv'.format(directory))

# %% [markdown]
# ### input features

# %%
X.columns
# Out:
# Index(['nuclear_avail', 'carbon_price', 'gas_price', 'solar_da', 'load_da',
#        'wind_da', 'rl_BE', 'rl_DE_LU', 'rl_ES', 'rl_IT_NORD', 'temp_mean',
#        'river_temp', 'river_flow_mean', 'rl_FR_ramp', 'run_off_gen',
#        'isworkingday', 'day_of_year_sin', 'day_of_year_cos', 'hour_sin',
#        'hour_cos'],
#       dtype='object')

# %%
X.plot(subplots=True, layout=(11,2), figsize=(22,22))
plt.tight_layout()
plt.show()

# %% [markdown]
# ### target: day-ahead price, agg_net_export

# %%
g = y_price.plot(figsize=(26,10))

# %%
g = y_export.plot(figsize=(26,10))
